# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/Users/vaibhav.srivastava/Downloads/ConvListTable - ConvListTable.csv')

# %%
df
# Out:
#                                   conv_id  \
# 0    d845e0ec-fa45-479a-94f4-84f39028cc90
# 1    d845e0ec-fa45-479a-94f4-84f39028cc90
# 2    a6432883-14a1-4925-803b-1102c06f0fcd
# 3    a6432883-14a1-4925-803b-1102c06f0fcd
# 4    a6432883-14a1-4925-803b-1102c06f0fcd
# ..                                    ...
# 438  87ae9545-7e20-40bb-a66b-fe37bab017e5
# 439  87ae9545-7e20-40bb-a66b-fe37bab017e5
# 440  b13f0c38-2400-4757-a8da-a95f54575212
# 441  d85c1639-59d2-4da8-9164-cdc5573ef30e
# 442  840e2633-8a97-4ce6-b319-3da6c1fb3d98
#
#                                   user_id           tenant_id  \
# 0    59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 1    59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 2    59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 3    59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 4    59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# ..                                    ...                 ...
# 438  59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 439  59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 440  c8d0a42c-31b1-4e31-b310-bdad39f02c08  TENANT_ID_FOR_TEST
# 441  c8d0a42c-31b1-4e31-b310-bdad39f02c08  TENANT_ID_FOR_TEST
# 442  c8d0a42c-31b1-4e31-b310-bdad39f02c08  TENANT_ID_FOR_TEST
#
#                                             tenant_url start_type  \
# 0    https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 1    https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 2    https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 3    https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 4    https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# ..                                                 ...        ...
# 438  https://champagne-clone-convassist-1.thoughtsp...        NLS
# 439  https://champagne-clone-convassist-1.thoughtsp...        NLS
# 440  https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 441  https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 442  https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
#
#                              worksheet_id  \
# 0    f67135f1-017f-4d66-8b21-112b51dcc9ed
# 1    f67135f1-017f-4d66-8b21-112b51dcc9ed
# 2    cd252e5c-b552-49a8-821d-3eadaa049cca
# 3    cd252e5c-b552-49a8-821d-3eadaa049cca
# 4    cd252e5c-b552-49a8-821d-3eadaa049cca
# ..                                    ...
# 438  cd252e5c-b552-49a8-821d-3eadaa049cca
# 439  cd252e5c-b552-49a8-821d-3eadaa049cca
# 440  54beb173-d755-42e0-8f73-4d4ec768114f
# 441  19bad14c-4b96-40fb-ac65-c564a02c4f29
# 442  19bad14c-4b96-40fb-ac65-c564a02c4f29
#
#                                    msg_id  \
# 0                                 INITIAL
# 1    8b6df0e4-97c8-42a3-a421-9300ccdaaadb
# 2                                 INITIAL
# 3    b05fe5b2-4ffc-4ab4-862f-7931a71735b9
# 4    25a5c86f-9f60-4635-8d45-08c7da15b7cf
# ..                                    ...
# 438                               INITIAL
# 439  6583f187-993f-4197-ba0e-f4d7295c8015
# 440                               INITIAL
# 441                               INITIAL
# 442                               INITIAL
#
#                                                  query  \
# 0    What is the total loan amount that does not me...
# 1                                   split it by region
# 2          What is the total sales of items this year?
# 3                  sales and quantity in ca last month
# 4    do sweaters or jackets sell better in the fall...
# ..                                                 ...
# 438       what was the jackets sales last year monthly
# 439                    what was item type laptop sales
# 440  What is the total ACV of opportunities booked,...
# 441  How many unique users have interacted with the...
# 442  How many unique users and queries were made ea...
#
#                                                    tml  \
# 0                                                  NaN
# 1    sum [Loan Amount] [Employee Title] [Loan Statu...
# 2                                                  NaN
# 3    [sales] [quantity purchased] [state] [date] = ...
# 4    sum [sales] [item type] [item type] = 'jackets...
# ..                                                 ...
# 438                                                NaN
# 439                 sum [sales] [item type] = 'laptop'
# 440                                                NaN
# 441                                                NaN
# 442                                                NaN
#
#                                                    sql eval comment  \
# 0    select SUM(Loan_Amount) from Lending_Club wher...          NaN
# 1    select Employee_Title, SUM(Loan_Amount) as Loa...            Y
# 2    select SUM(sales), item_type from _Sample_Reta...          NaN
# 3    select SUM(sales), SUM(quantity_purchased), st...            Y
# 4    select item_type, SUM(sales) from __Sample_Ret...            N
# ..                                                 ...          ...
# 438                                                NaN          NaN
# 439  SELECT SUM(sales) FROM __Sample_Retail_Apparel...            Y
# 440  select SUM(Opportunity_ACV), QUARTERLY(Opportu...          NaN
# 441  select Unique_Users, MONTHLY(Activity_DATE) fr...          NaN
# 442  select Unique_Users, Account_Name, MONTHLY(Act...          NaN
#
#          error type Unnamed: 12
# 0               NaN         NaN
# 1               NaN         NaN
# 2               NaN         NaN
# 3               NaN         NaN
# 4    filter missing         NaN
# ..              ...         ...
# 438             NaN         NaN
# 439             NaN         NaN
# 440             NaN         NaN
# 441             NaN         NaN
# 442             NaN         NaN
#
# [443 rows x 13 columns]

# %%
df['eval comment'].value_counts()
# Out:
# Duplicate       107
# Y                96
# N                29
# no sql/tml        5
# only INITIAL      4
# Name: eval comment, dtype: int64

# %%
# Data only for unique msgs

unique_msg_df = df[df['eval comment'].isin(['Y', 'N'])]

# %%
unique_msg_df
# Out:
#                                   conv_id  \
# 1    d845e0ec-fa45-479a-94f4-84f39028cc90
# 3    a6432883-14a1-4925-803b-1102c06f0fcd
# 4    a6432883-14a1-4925-803b-1102c06f0fcd
# 6    4771c81a-abae-4b57-908d-fda6a330c219
# 8    ff2539e1-e093-486b-b7a1-1092f6d6794d
# ..                                    ...
# 424  49e43302-0611-493e-98ab-7964db3a7bb0
# 426  127ba2ef-fd41-4415-add2-82b9c297668c
# 432  9aba918b-6c7a-4061-a562-f8c1d9b838ee
# 433  9aba918b-6c7a-4061-a562-f8c1d9b838ee
# 439  87ae9545-7e20-40bb-a66b-fe37bab017e5
#
#                                   user_id           tenant_id  \
# 1    59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 3    59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 4    59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 6    59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 8    59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# ..                                    ...                 ...
# 424  df8a0eff-d455-45f4-935d-e1bdc276c6d1  TENANT_ID_FOR_TEST
# 426  59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 432  df8a0eff-d455-45f4-935d-e1bdc276c6d1  TENANT_ID_FOR_TEST
# 433  df8a0eff-d455-45f4-935d-e1bdc276c6d1  TENANT_ID_FOR_TEST
# 439  59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
#
#                                             tenant_url start_type  \
# 1    https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 3    https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 4    https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 6    https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 8    https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# ..                                                 ...        ...
# 424  https://champagne-clone-convassist-1.thoughtsp...        NLS
# 426  https://champagne-clone-convassist-1.thoughtsp...        NLS
# 432  https://champagne-clone-convassist-1.thoughtsp...        NLS
# 433  https://champagne-clone-convassist-1.thoughtsp...        NLS
# 439  https://champagne-clone-convassist-1.thoughtsp...        NLS
#
#                              worksheet_id  \
# 1    f67135f1-017f-4d66-8b21-112b51dcc9ed
# 3    cd252e5c-b552-49a8-821d-3eadaa049cca
# 4    cd252e5c-b552-49a8-821d-3eadaa049cca
# 6    54beb173-d755-42e0-8f73-4d4ec768114f
# 8    54beb173-d755-42e0-8f73-4d4ec768114f
# ..                                    ...
# 424  37e44582-d602-4fcf-ab14-e20d378faa8b
# 426  971680a5-731c-4b6d-bfb6-1dd19745a020
# 432  37e44582-d602-4fcf-ab14-e20d378faa8b
# 433  37e44582-d602-4fcf-ab14-e20d378faa8b
# 439  cd252e5c-b552-49a8-821d-3eadaa049cca
#
#                                    msg_id  \
# 1    8b6df0e4-97c8-42a3-a421-9300ccdaaadb
# 3    b05fe5b2-4ffc-4ab4-862f-7931a71735b9
# 4    25a5c86f-9f60-4635-8d45-08c7da15b7cf
# 6    e5efbd00-2127-48f1-be67-0acaf0ab4b14
# 8    5b2e1c8a-a2c5-4ea6-89c6-baa3a75736d6
# ..                                    ...
# 424  0305fa32-dbeb-4128-b78e-1e02c72300b1
# 426  226a6c8b-e4e9-42ee-81b9-36a3bae5de01
# 432  a392ea45-86a9-4e83-a19d-622d8b531a26
# 433  fd38230d-0147-4e88-894a-534408bd3999
# 439  6583f187-993f-4197-ba0e-f4d7295c8015
#
#                                                  query  \
# 1                                   split it by region
# 3                  sales and quantity in ca last month
# 4    do sweaters or jackets sell better in the fall...
# 6                            show account name as well
# 8                                    show account name
# ..                                                 ...
# 424              where were those flights flying into?
# 426  How many unique customer accounts asked a ques...
# 432            how many of those flights were delayed?
# 433         where were all those flights departing to?
# 439                    what was item type laptop sales
#
#                                                    tml  \
# 1    sum [Loan Amount] [Employee Title] [Loan Statu...
# 3    [sales] [quantity purchased] [state] [date] = ...
# 4    sum [sales] [item type] [item type] = 'jackets...
# 6    [Opportunity Count] [Competitive Wins] [Compet...
# 8                                       [Account Name]
# ..                                                 ...
# 424  count [ORIGIN_MESSAGE_ID] [ARRIVAL_IATA_AIRPOR...
# 426  unique count [Account ID] [Formula = Community...
# 432  [Number of Flights] [DEPARTURE_COUNTRY_CODE] =...
# 433  count [ORIGIN_MESSAGE_ID] [ARRIVAL_IATA_AIRPOR...
# 439                 sum [sales] [item type] = 'laptop'
#
#                                                    sql eval comment  \
# 1    select Employee_Title, SUM(Loan_Amount) as Loa...            Y
# 3    select SUM(sales), SUM(quantity_purchased), st...            Y
# 4    select item_type, SUM(sales) from __Sample_Ret...            N
# 6    SELECT Account_Name, Opportunity_Count, Compet...            Y
# 8                        select Account_Name from GTM;            Y
# ..                                                 ...          ...
# 424  SELECT ARRIVAL_IATA_AIRPORT_CODE, COUNT(*) AS ...            Y
# 426  SELECT COUNT(DISTINCT Account_ID) FROM _GTM_Co...            N
# 432  SELECT Number_of_Flights FROM _OAG_Flight_Samp...            Y
# 433  SELECT ARRIVAL_IATA_AIRPORT_CODE, COUNT(*) as ...            Y
# 439  SELECT SUM(sales) FROM __Sample_Retail_Apparel...            Y
#
#          error type               Unnamed: 12
# 1               NaN                       NaN
# 3               NaN                       NaN
# 4    filter missing                       NaN
# 6               NaN                       NaN
# 8               NaN                       NaN
# ..              ...                       ...
# 424             NaN                       NaN
# 426          Others  SQL also seems incorrect
# 432             NaN                       NaN
# 433             NaN                       NaN
# 439             NaN                       NaN
#
# [125 rows x 13 columns]

# %%
# Count and Percentage of unique msgs


value_counts = unique_msg_df['eval comment'].value_counts()
total_count = unique_msg_df['eval comment'].count()

percentage_counts = (value_counts / total_count) * 100

print("Value Counts:")
print(value_counts)

print("\nPercentage Counts:")
print(percentage_counts)

print("\nTotal Count:")
print(total_count)
# Out:
# Value Counts:
# Y    96
# N    29
# Name: eval comment, dtype: int64
#
# Percentage Counts:
# Y    76.8
# N    23.2
# Name: eval comment, dtype: float64
#
# Total Count:
# 125

# %%
# BAR GRAPH


plt.figure(figsize=(8, 6))
ax = sns.countplot(data=unique_msg_df, x='eval comment')

total = len(unique_msg_df)
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height() / total)
    x = p.get_x() + p.get_width() / 2
    y = p.get_height() + 0.01
    ax.annotate(percentage, (x, y), ha='center')

plt.title("Count of Unique Messages")
plt.xlabel("eval Comment")
plt.ylabel("Count")
plt.show()

# %%
#count of error types(N)

unique_msg_df['error type'].value_counts()
# Out:
# Keyword translation issue    12
# Others                        9
# Formula                       4
# filter missing                2
# Subquery                      1
# Date filter                   1
# Name: error type, dtype: int64

# %%
# Total no. of unique conv.

unique_conv_id_count = unique_msg_df['conv_id'].nunique()
print("Total Unique Count of 'conv_id':", unique_conv_id_count)
# Out:
# Total Unique Count of 'conv_id': 78

# %%
# DataFrame for unique conv with 1 msg

# %%
# Filter the DataFrame to include only 'Y' and 'N' values
filtered_df = unique_msg_df[unique_msg_df['eval comment'].isin(['Y', 'N'])]

# Count occurrences of each 'conv_id'
conv_id_counts = filtered_df['conv_id'].value_counts()

# Filter 'conv_id' with count equal to 1
selected_conv_ids = conv_id_counts[conv_id_counts == 1].index

# Filter the DataFrame based on selected 'conv_id'
count1_result_df = filtered_df[filtered_df['conv_id'].isin(selected_conv_ids)]

# Now, result_df contains rows where 'eval comment' is 'Y' or 'N' and 'conv_id' count is 1

# %%
count1_result_df
# Out:
#                                   conv_id  \
# 1    d845e0ec-fa45-479a-94f4-84f39028cc90
# 6    4771c81a-abae-4b57-908d-fda6a330c219
# 8    ff2539e1-e093-486b-b7a1-1092f6d6794d
# 18   73e1b14e-e236-4683-82a1-38a5b102629d
# 21   ebb98382-25d8-4d21-9eae-1b93c25a234a
# 30   49ff257f-2330-407b-80b1-e0f21938b065
# 41   204b5282-53b3-4b33-b5b8-7675a28b27d0
# 45   a8a59b73-295c-481d-ad2d-5d33e29e3f8c
# 48   2ae9d29e-c2c8-4c6d-aa56-ba8858ba4bb2
# 61   4e333f95-7832-407a-a11c-799c88f54992
# 69   2669b50f-a86f-4008-be61-a707fb2e1d05
# 81   a267ade8-776e-45fc-91f2-fbf0056e9d7e
# 97   8c656c3c-52ad-4948-bdf8-ca8e39be8503
# 104  20a77824-07ea-494b-aab3-53740114e5f2
# 114  c599fc7c-8a36-437d-9480-2e48e8358688
# 116  b7fb99b0-3776-492a-8adc-664a40006b4d
# 142  bd470bed-b696-4564-b661-cb2cf55dddbe
# 157  5b285ed8-4a5e-4e0b-81c4-df925e346d5a
# 197  8e4ffad4-cbfc-4045-9524-4f39ec4c9615
# 218  9edc70c5-c588-4aef-9d16-bf14eceedaad
# 230  2ac8fc29-37b7-4e8b-816e-6ef406f8a076
# 235  d659144e-83ce-4003-be30-8b5429e5aa93
# 253  b5a3a4f7-bf6f-441e-931a-9a29b428bbde
# 255  b17e6cd2-b40f-42b0-a818-8d52640b0932
# 261  63144b8c-a261-4631-a776-33adb644b962
# 263  764a8679-93a4-44e2-b44d-08666cfd3541
# 289  18e1ac37-a3d6-4e18-8066-28d549657904
# 294  011f5147-34eb-44cb-9e82-5e9e780af854
# 311  9e612af1-dae6-444e-8443-c59365d4bc5e
# 320  168bd796-9324-479c-9351-40e06b8e2720
# 327  b1f96ebc-b7af-42c9-a96d-4bc46e31f64d
# 332  9fa871b5-d6d9-44a1-af6f-7dfd924c88af
# 345  9c0992ff-ef50-48a9-9124-d6b4fcee1077
# 348  85092b14-e078-431b-afae-205d93978460
# 358  8770ddcb-a6dd-4a85-8265-a4515d433c54
# 363  fbb59e8b-d0ac-4c01-bfc3-fd322d66a956
# 365  e2a2c479-b209-47d7-ab6b-69db38d5f533
# 367  1223c6b3-b9e0-4c45-bb3d-a6deafde04f2
# 369  f45f97d3-45e2-4bb4-a77a-0f27445be4eb
# 374  a51a2f8f-a29f-4929-af43-f5089c82cd38
# 376  c8980539-5663-4b09-b234-9b59bf76bc22
# 378  920aa415-7d4b-41ba-8588-34abc9fbde75
# 382  4227d3a2-4360-4fc6-87e7-3403ef256c78
# 415  aa9e05a8-b4cd-46c7-a643-03cbfe875275
# 424  49e43302-0611-493e-98ab-7964db3a7bb0
# 426  127ba2ef-fd41-4415-add2-82b9c297668c
# 439  87ae9545-7e20-40bb-a66b-fe37bab017e5
#
#                                   user_id           tenant_id  \
# 1    59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 6    59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 8    59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 18   59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 21   59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 30   59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 41   59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 45   59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 48   59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 61   df8a0eff-d455-45f4-935d-e1bdc276c6d1  TENANT_ID_FOR_TEST
# 69   59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 81   59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 97   59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 104  59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 114  59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 116  59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 142  59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 157  59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 197  59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 218  59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 230  df8a0eff-d455-45f4-935d-e1bdc276c6d1  TENANT_ID_FOR_TEST
# 235  df8a0eff-d455-45f4-935d-e1bdc276c6d1  TENANT_ID_FOR_TEST
# 253  df8a0eff-d455-45f4-935d-e1bdc276c6d1  TENANT_ID_FOR_TEST
# 255  df8a0eff-d455-45f4-935d-e1bdc276c6d1  TENANT_ID_FOR_TEST
# 261  c8d0a42c-31b1-4e31-b310-bdad39f02c08  TENANT_ID_FOR_TEST
# 263  c8d0a42c-31b1-4e31-b310-bdad39f02c08  TENANT_ID_FOR_TEST
# 289  a7b73dd0-677e-4379-aecb-f63b5fdd2ff8  TENANT_ID_FOR_TEST
# 294  a7b73dd0-677e-4379-aecb-f63b5fdd2ff8  TENANT_ID_FOR_TEST
# 311  c8d0a42c-31b1-4e31-b310-bdad39f02c08  TENANT_ID_FOR_TEST
# 320  c8d0a42c-31b1-4e31-b310-bdad39f02c08  TENANT_ID_FOR_TEST
# 327  59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 332  59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 345  c8d0a42c-31b1-4e31-b310-bdad39f02c08  TENANT_ID_FOR_TEST
# 348  c8d0a42c-31b1-4e31-b310-bdad39f02c08  TENANT_ID_FOR_TEST
# 358  df8a0eff-d455-45f4-935d-e1bdc276c6d1  TENANT_ID_FOR_TEST
# 363  c8d0a42c-31b1-4e31-b310-bdad39f02c08  TENANT_ID_FOR_TEST
# 365  c8d0a42c-31b1-4e31-b310-bdad39f02c08  TENANT_ID_FOR_TEST
# 367  c8d0a42c-31b1-4e31-b310-bdad39f02c08  TENANT_ID_FOR_TEST
# 369  c8d0a42c-31b1-4e31-b310-bdad39f02c08  TENANT_ID_FOR_TEST
# 374  c8d0a42c-31b1-4e31-b310-bdad39f02c08  TENANT_ID_FOR_TEST
# 376  c8d0a42c-31b1-4e31-b310-bdad39f02c08  TENANT_ID_FOR_TEST
# 378  df8a0eff-d455-45f4-935d-e1bdc276c6d1  TENANT_ID_FOR_TEST
# 382  df8a0eff-d455-45f4-935d-e1bdc276c6d1  TENANT_ID_FOR_TEST
# 415  59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 424  df8a0eff-d455-45f4-935d-e1bdc276c6d1  TENANT_ID_FOR_TEST
# 426  59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 439  59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
#
#                                             tenant_url start_type  \
# 1    https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 6    https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 8    https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 18   https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 21   https://champagne-clone-convassist-1.thoughtsp...        NLS
# 30   https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 41   https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 45   https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 48   https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 61   https://champagne-clone-convassist-1.thoughtsp...        NLS
# 69   https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 81   https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 97   https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 104  https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 114  https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 116  https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 142  https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 157  https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 197  https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 218  https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 230  https://champagne-clone-convassist-1.thoughtsp...        NLS
# 235  https://champagne-clone-convassist-1.thoughtsp...        NLS
# 253  https://champagne-clone-convassist-1.thoughtsp...        NLS
# 255  https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 261  https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 263  https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 289  https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 294  https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 311  https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 320  https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 327  https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 332  https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 345  https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 348  https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 358  https://champagne-clone-convassist-1.thoughtsp...        NLS
# 363  https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 365  https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 367  https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 369  https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 374  https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 376  https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 378  https://champagne-clone-convassist-1.thoughtsp...        NLS
# 382  https://champagne-clone-convassist-1.thoughtsp...        NLS
# 415  https://champagne-clone-convassist-1.thoughtsp...        NLS
# 424  https://champagne-clone-convassist-1.thoughtsp...        NLS
# 426  https://champagne-clone-convassist-1.thoughtsp...        NLS
# 439  https://champagne-clone-convassist-1.thoughtsp...        NLS
#
#                              worksheet_id  \
# 1    f67135f1-017f-4d66-8b21-112b51dcc9ed
# 6    54beb173-d755-42e0-8f73-4d4ec768114f
# 8    54beb173-d755-42e0-8f73-4d4ec768114f
# 18   f67135f1-017f-4d66-8b21-112b51dcc9ed
# 21   54beb173-d755-42e0-8f73-4d4ec768114f
# 30   cd252e5c-b552-49a8-821d-3eadaa049cca
# 41   cd252e5c-b552-49a8-821d-3eadaa049cca
# 45   cd252e5c-b552-49a8-821d-3eadaa049cca
# 48   cd252e5c-b552-49a8-821d-3eadaa049cca
# 61   cd252e5c-b552-49a8-821d-3eadaa049cca
# 69   f67135f1-017f-4d66-8b21-112b51dcc9ed
# 81   54beb173-d755-42e0-8f73-4d4ec768114f
# 97   971680a5-731c-4b6d-bfb6-1dd19745a020
# 104  54beb173-d755-42e0-8f73-4d4ec768114f
# 114  f67135f1-017f-4d66-8b21-112b51dcc9ed
# 116  54beb173-d755-42e0-8f73-4d4ec768114f
# 142  54beb173-d755-42e0-8f73-4d4ec768114f
# 157  54beb173-d755-42e0-8f73-4d4ec768114f
# 197  54beb173-d755-42e0-8f73-4d4ec768114f
# 218  1345432e-e505-46f2-b505-d90e4e5437cc
# 230  06c128d3-54e6-4748-a3e4-2866b49cee84
# 235  06c128d3-54e6-4748-a3e4-2866b49cee84
# 253  06c128d3-54e6-4748-a3e4-2866b49cee84
# 255  06c128d3-54e6-4748-a3e4-2866b49cee84
# 261  19bad14c-4b96-40fb-ac65-c564a02c4f29
# 263  19bad14c-4b96-40fb-ac65-c564a02c4f29
# 289  cd252e5c-b552-49a8-821d-3eadaa049cca
# 294  cd252e5c-b552-49a8-821d-3eadaa049cca
# 311  cda5cb86-d4ae-40ed-b919-312d409ab019
# 320  19bad14c-4b96-40fb-ac65-c564a02c4f29
# 327  cda5cb86-d4ae-40ed-b919-312d409ab019
# 332  cda5cb86-d4ae-40ed-b919-312d409ab019
# 345  54beb173-d755-42e0-8f73-4d4ec768114f
# 348  971680a5-731c-4b6d-bfb6-1dd19745a020
# 358  cd252e5c-b552-49a8-821d-3eadaa049cca
# 363  f67135f1-017f-4d66-8b21-112b51dcc9ed
# 365  54beb173-d755-42e0-8f73-4d4ec768114f
# 367  54beb173-d755-42e0-8f73-4d4ec768114f
# 369  b2d24878-0150-4c1e-a74c-bfc46cc4a682
# 374  b2d24878-0150-4c1e-a74c-bfc46cc4a682
# 376  54beb173-d755-42e0-8f73-4d4ec768114f
# 378  cd252e5c-b552-49a8-821d-3eadaa049cca
# 382  cd252e5c-b552-49a8-821d-3eadaa049cca
# 415  cda5cb86-d4ae-40ed-b919-312d409ab019
# 424  37e44582-d602-4fcf-ab14-e20d378faa8b
# 426  971680a5-731c-4b6d-bfb6-1dd19745a020
# 439  cd252e5c-b552-49a8-821d-3eadaa049cca
#
#                                    msg_id  \
# 1    8b6df0e4-97c8-42a3-a421-9300ccdaaadb
# 6    e5efbd00-2127-48f1-be67-0acaf0ab4b14
# 8    5b2e1c8a-a2c5-4ea6-89c6-baa3a75736d6
# 18   290d104f-ed28-462a-ac24-01cb2ac5ff35
# 21   5a825c58-88d4-4f76-b7c0-fda4a9fbcd53
# 30   e8aba465-c645-4cb7-9f79-08bd1a9acb8d
# 41   de86a573-2267-4a40-881b-2b54ca19d81f
# 45   817e4753-c363-455c-8f23-18467538a124
# 48   1fb3ba58-61c1-46ec-99c8-346c5c0c6ce1
# 61   6e1d399e-ed3a-4925-b9a6-5f7fa5d73e04
# 69   cc866738-5199-4107-9da6-abcc5f6ee3ed
# 81   9b242866-75cf-4ab8-b5ef-975f7c020a78
# 97   18f4cff9-1d57-4bf9-bd15-4c9796947123
# 104  aa3c1d6b-63c2-45f5-8f3f-79ac44c472fd
# 114  85e88174-7974-40b8-82fd-daf667807f92
# 116  4dab7d31-7c51-4e4c-a800-065bbb8bf0b5
# 142  9a0596f1-5287-42a9-9085-b335a65d7448
# 157  1c4038b4-cff8-4a94-b85e-a41f18361d8c
# 197  2b825f52-83e1-4db1-a718-7d8df53a9a43
# 218  d6c2bc75-ba91-444e-b34b-9e131d6fec6a
# 230  86b4e4d0-5787-4f8f-b7dc-d1bbb990328e
# 235  f2f34986-8079-44af-a5c5-57459efd53fd
# 253  6b944a6e-1f96-4dfa-8782-0c1460b566c7
# 255  d0e573f3-53a1-489f-adae-882f6588c833
# 261  d797af75-0788-4094-a744-659ec8da457c
# 263  18bfd645-ae79-4194-b1cd-92cac45fe604
# 289  ab03e5b9-e9b3-45e9-8f95-65666bb79ec7
# 294  9bced9f9-130b-4967-8838-b5e39790184a
# 311  0af8c8fa-7bec-457a-a149-12b4e848d5c7
# 320  b4bc13eb-2583-4f4d-8ea9-6aac8ffa22af
# 327  0b1047c4-b24e-4186-bb23-7ccf8aa85b35
# 332  1f4d74b7-b4e1-4aa5-b1bc-832d71affb22
# 345  36124f54-1b06-4487-8a84-5ec1628b180c
# 348  114bf1d4-f4d7-453e-a810-9b19cc261f7d
# 358  a805888e-2e67-405f-8170-8ef0956b00ee
# 363  6866a185-5dd7-41e8-9a16-b1e5ebe12c18
# 365  a5328631-2a88-48e3-a2b0-13511b8b4db5
# 367  9c124579-39e0-45e7-a343-a11c3ee07520
# 369  b6f83dcb-dd0a-42d8-bc5a-d9b682698c6d
# 374  8f5a720b-3608-4200-9fa1-368f50c773e0
# 376  ef09cddd-9fa6-4e6f-a330-0051c9ea907e
# 378  c95800af-b0b5-4e50-a624-677a4398a7a1
# 382  f3615bf9-42a9-4239-b3f7-261fd0a69bf4
# 415  daf0eb8c-080b-40c2-9364-e15bc8734acc
# 424  0305fa32-dbeb-4128-b78e-1e02c72300b1
# 426  226a6c8b-e4e9-42ee-81b9-36a3bae5de01
# 439  6583f187-993f-4197-ba0e-f4d7295c8015
#
#                                                  query  \
# 1                                   split it by region
# 6                            show account name as well
# 8                                    show account name
# 18      can you show comparison of grade a and grade b
# 21                           show me acv for this year
# 30                                 show me total data?
# 41                                        show me data
# 45                       show me a cool complex chart?
# 48           show me for south and only top 5 products
# 61                  can I see it for the last 82 days?
# 69                           add average interest rate
# 81   what was the competitive win percentage last q...
# 97     break it down by account name for november 2023
# 104  what was the competitive win percentage last q...
# 114                                    show me for bad
# 116  what was the competitive win percentage last q...
# 142                                   show me all data
# 157                           can you show me all data
# 197  what was the competitive win percentage last q...
# 218                                   Split it by team
# 230                          break this down by gender
# 235                               what about ethnicity
# 253            whats the share of gender distribution?
# 255               where did those new hires come from?
# 261                 Can you only show this for cloud ?
# 263    Can you show this for  not installed clusters ?
# 289                         what were my top 3 regions
# 294  drill down into november by type of product an...
# 311  Can you show the account names and acv attache...
# 320  What is the descending order of unique users f...
# 327                                      show me sales
# 332                          i want account owner name
# 345  What are the daily or weekly login trends for ...
# 348  How many unique customer accounts asked a ques...
# 358                    where were those products sold?
# 363                                   split by purpose
# 365  What is the distribution of M0 opportunities b...
# 367                               break it down status
# 369  What is the MQL conversion rate and volume by ...
# 374  What are the common reasons for closing MQLs b...
# 376  what was the competitive win percentage last q...
# 378  what were the regions where these products wer...
# 382            where were the most travel duffel sold?
# 415  Can you show it by quarter for last 4 quarter ...
# 424              where were those flights flying into?
# 426  How many unique customer accounts asked a ques...
# 439                    what was item type laptop sales
#
#                                                    tml  \
# 1    sum [Loan Amount] [Employee Title] [Loan Statu...
# 6    [Opportunity Count] [Competitive Wins] [Compet...
# 8                                       [Account Name]
# 18   sum [Loan Amount] [Purpose] in ( [Purpose] [Pu...
# 21                          [Opportunity RD Gross ACV]
# 30                           sum [sales] count [sales]
# 41   [sales] [date] [date].monthly [item type] [dat...
# 45   top 10 by sum [sales] [item type] [region] [Fo...
# 48   sum [sales] [region] [item type] [date] = 'thi...
# 61   top 10 by sum [sales] [product] [date] = 'last...
# 69   sum [Loan Amount] [Formula = avg interest rate...
# 81   [Case Last Modified Time] = 'last quarter' [TS...
# 97   [Sign Ups] [Account Name] [Community Network M...
# 104  [Opportunity Created Date] = 'last quarter' [O...
# 114  count [Employment Length In Yrs] [Employment L...
# 116  [Opportunity Created Date] = 'last quarter' [T...
# 142  [Competitive Win %] [Competitive Wins] [Mixpan...
# 157  [Opportunity Mode Data Compute Total Purchased...
# 197  [Formula = competitive win percentage] [Opport...
# 218          sum [Actual] sum [TARGET] [TEAM] [REGION]
# 230                     count [Supervisor ID] [Gender]
# 235  count [Employee ID] [Ethnicity] [Hire Date] = ...
# 253                     count [Supervisor ID] [Gender]
# 255  count [Supervisor ID] [Hire Date] [Hire Date]....
# 261  unique count [Unique Users] [Activity DATE].mo...
# 263  count [Unique Users] [Activity DATE].monthly [...
# 289                      top 3 by sum [sales] [region]
# 294  top 25 by sum [sales] [product] [item type] = ...
# 311  [Vivun Account Gap Amount] [Account Name] [Viv...
# 320  unique count [User GUID] [Account Name] [Accou...
# 327  [User Department] [User Name] [User Title] [Us...
# 332  top 10 by sum [# of Opp & Acct Gaps] [Vivun Pr...
# 345  unique count [Person ID] [TS User Registration...
# 348  unique count [Account ID] [Community User Feed...
# 358  top 10 by sum [sales] [city] [region] [state] ...
# 363  sum [Loan Amount] [Purpose] [Loan Status] = 'c...
# 365  count [Opportunity M0 Created Count] [Opportun...
# 367  count [Credit Capped Paid Count] [Opportunity ...
# 369  sum [Person Mqls Count] average [Person MQL to...
# 374  count [FT User Team ID] [Person Closed Reason]...
# 376                     [Opportunity Type] = 'renewal'
# 378  sum [sales] [region] [product] in ( [product] ...
# 382  top 1 by sum [quantity purchased] [state] [cit...
# 415  count [Vivun Deliverable Video Link] [Vivun Pr...
# 424  count [ORIGIN_MESSAGE_ID] [ARRIVAL_IATA_AIRPOR...
# 426  unique count [Account ID] [Formula = Community...
# 439                 sum [sales] [item type] = 'laptop'
#
#                                                    sql eval comment  \
# 1    select Employee_Title, SUM(Loan_Amount) as Loa...            Y
# 6    SELECT Account_Name, Opportunity_Count, Compet...            Y
# 8                        select Account_Name from GTM;            Y
# 18   select SUM(Loan_Amount), Grade from _Lending_C...            Y
# 21   SELECT SUM(Opportunity_RD_Gross_ACV) FROM _GTM...            N
# 30   select SUM(sales) as total_sales, COUNT(*) as ...            N
# 41   SELECT date, item_type, sales FROM __Sample_Re...            Y
# 45   select region, item_type, SUM(sales) as total_...            N
# 48   select SUM(sales), item_type, region from _Sam...            Y
# 61   SELECT product, SUM(sales) as total_sales FROM...            Y
# 69   select Purpose, SUM(Loan_Amount) as Total_Loan...            Y
# 81   select sum(Competitive_Wins) * 100.0 / sum(Opp...            N
# 97   SELECT Account_Name, Sign_Ups FROM _GTM_Commun...            Y
# 104  select sum(Competitive_Wins) * 100.0 / sum(Opp...            N
# 114  select Bad_Loan, Employment_Length_In_Yrs, COU...            Y
# 116  SELECT ROUND(100.0 * SUM(Competitive_Wins) / S...            N
# 142  select Competitive_Wins_Summary, Competitive_W...            N
# 157                                select * from _GTM;            N
# 197  select sum(Competitive_Wins) * 100.0 / sum(Opp...            Y
# 218  select SUM(Actual), REGION, TEAM, SUM(TARGET) ...            Y
# 230  SELECT Gender, COUNT(*) as Number_of_Employees...            N
# 235  SELECT Ethnicity, COUNT(Employee_ID) as Number...            Y
# 253  SELECT Gender, COUNT(*) AS Gender_Count FROM _...            Y
# 255  SELECT Hire_Date, Current_Location, COUNT(*) F...            Y
# 261  SELECT COUNT(DISTINCT Unique_Users), EXTRACT(M...            Y
# 263  SELECT COUNT(Unique_Users), EXTRACT(MONTH FROM...            Y
# 289  SELECT region, SUM(sales) as total_sales FROM ...            Y
# 294  select product, SUM(sales) from _Sample_Retail...            Y
# 311  select Account_Name, Vivun_Account_Gap_Amount ...            Y
# 320  select Account_Name, COUNT(DISTINCT User_GUID)...            Y
# 327  select User_Name, User_Title, User_Department ...            Y
# 332  select Account_Owner_Name, Vivun_Product_Gap_P...            Y
# 345  SELECT COUNT(DISTINCT Person_ID), DATE(TS_User...            Y
# 348  SELECT COUNT(DISTINCT Account_ID) FROM _GTM_Co...            Y
# 358  SELECT region, state, city, SUM(sales) as tota...            Y
# 363  select Purpose, SUM(Loan_Amount) as Loan_Amoun...            Y
# 365  select Opportunity_Closed_Won_Owner_Team, coun...            Y
# 367  SELECT Opportunity_Status, COUNT(*) FROM _GTM ...            N
# 369  SELECT Opportunity_Region_Segment, SUM(Person_...            Y
# 374  SELECT Person_Closed_Reason, COUNT(*) as count...            Y
# 376  select (sum(Competitive_Wins) * 100.0 / sum(Op...            N
# 378  SELECT region, SUM(sales) FROM __Sample_Retail...            Y
# 382  SELECT city, state, SUM(quantity_purchased) as...            Y
# 415  SELECT COUNT(*), QUARTER(Vivun_Product_Gap_Las...            Y
# 424  SELECT ARRIVAL_IATA_AIRPORT_CODE, COUNT(*) AS ...            Y
# 426  SELECT COUNT(DISTINCT Account_ID) FROM _GTM_Co...            N
# 439  SELECT SUM(sales) FROM __Sample_Retail_Apparel...            Y
#
#                     error type               Unnamed: 12
# 1                          NaN                       NaN
# 6                          NaN                       NaN
# 8                          NaN                       NaN
# 18                         NaN                       NaN
# 21   Keyword translation issue                       NaN
# 30   Keyword translation issue                       NaN
# 41                         NaN                       NaN
# 45                      Others  SQL also seems incorrect
# 48                         NaN                       NaN
# 61                         NaN                       NaN
# 69                         NaN                       NaN
# 81   Keyword translation issue                       NaN
# 97                         NaN                       NaN
# 104                    Formula                       NaN
# 114                        NaN                       NaN
# 116                    Formula                       NaN
# 142                     Others                       NaN
# 157  Keyword translation issue                       NaN
# 197                        NaN                       NaN
# 218                        NaN                       NaN
# 230  Keyword translation issue                       NaN
# 235                        NaN                       NaN
# 253                        NaN                       NaN
# 255                        NaN                       NaN
# 261                        NaN                       NaN
# 263                        NaN                       NaN
# 289                        NaN                       NaN
# 294                        NaN                       NaN
# 311                        NaN                       NaN
# 320                        NaN                       NaN
# 327                        NaN                       NaN
# 332                        NaN                       NaN
# 345                        NaN                       NaN
# 348                        NaN                       NaN
# 358                        NaN                       NaN
# 363                        NaN                       NaN
# 365                        NaN                       NaN
# 367                     Others                       NaN
# 369                        NaN                       NaN
# 374                        NaN                       NaN
# 376                    Formula                       NaN
# 378                        NaN                       NaN
# 382                        NaN                       NaN
# 415                        NaN                       NaN
# 424                        NaN                       NaN
# 426                     Others  SQL also seems incorrect
# 439                        NaN                       NaN

# %%
# Total count of coversation with 1 msg

new_unique_conv_id_count = count1_result_df['conv_id'].nunique()
new_unique_conv_id_count
# Out:
# 47

# %%
# Count & Precentage -  of success and failure for conv with 1 msg


# Filter the DataFrame to include only 'Y' and 'N' values
filtered_df = count1_result_df[unique_msg_df['eval comment'].isin(['Y', 'N'])]

# Count occurrences of each value in 'eval comment'
eval_comment_counts = filtered_df['eval comment'].value_counts()

# Calculate percentage
eval_comment_percentage = eval_comment_counts / eval_comment_counts.sum() * 100

# Display the results
print("Count of 'Y' and 'N' in eval comment:")
print(eval_comment_counts)
print("\nPercentage of 'Y' and 'N' in eval comment:")
print(eval_comment_percentage)
# Out:
# Count of 'Y' and 'N' in eval comment:
# Y    35
# N    12
# Name: eval comment, dtype: int64
#
# Percentage of 'Y' and 'N' in eval comment:
# Y    74.468085
# N    25.531915
# Name: eval comment, dtype: float64

# %%
# DataFrame for unique conv with >=2 msg

# %%
# Filter the DataFrame to include only 'Y' and 'N' values
filtered_df = unique_msg_df[unique_msg_df['eval comment'].isin(['Y', 'N'])]

# Count occurrences of each 'conv_id'
conv_id_counts = filtered_df['conv_id'].value_counts()

# Filter 'conv_id' with count equal to 2
selected_conv_ids = conv_id_counts[conv_id_counts >= 2].index

# Filter the DataFrame based on selected 'conv_id'
new_result_df = filtered_df[filtered_df['conv_id'].isin(selected_conv_ids)]

# Now, result_df contains rows where 'eval comment' is 'Y' or 'N' and 'conv_id' count is >=2

# %%
new_result_df
# Out:
#                                   conv_id  \
# 3    a6432883-14a1-4925-803b-1102c06f0fcd
# 4    a6432883-14a1-4925-803b-1102c06f0fcd
# 12   319aa44a-0092-4d41-9256-8f19241dfe15
# 13   319aa44a-0092-4d41-9256-8f19241dfe15
# 25   de1b4b55-5bf6-432c-a0bd-7344da74229f
# ..                                    ...
# 372  57cae596-d0f4-4022-ae27-1426507a2622
# 417  ad0a5512-73b0-45f8-b02e-4dcfbc4f545e
# 418  ad0a5512-73b0-45f8-b02e-4dcfbc4f545e
# 432  9aba918b-6c7a-4061-a562-f8c1d9b838ee
# 433  9aba918b-6c7a-4061-a562-f8c1d9b838ee
#
#                                   user_id           tenant_id  \
# 3    59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 4    59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 12   59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 13   59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 25   59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# ..                                    ...                 ...
# 372  c8d0a42c-31b1-4e31-b310-bdad39f02c08  TENANT_ID_FOR_TEST
# 417  59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 418  59481331-ee53-42be-a548-bd87be6ddd4a  TENANT_ID_FOR_TEST
# 432  df8a0eff-d455-45f4-935d-e1bdc276c6d1  TENANT_ID_FOR_TEST
# 433  df8a0eff-d455-45f4-935d-e1bdc276c6d1  TENANT_ID_FOR_TEST
#
#                                             tenant_url start_type  \
# 3    https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 4    https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 12   https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 13   https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 25   https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# ..                                                 ...        ...
# 372  https://champagne-clone-convassist-1.thoughtsp...  LIVEBOARD
# 417  https://champagne-clone-convassist-1.thoughtsp...        NLS
# 418  https://champagne-clone-convassist-1.thoughtsp...        NLS
# 432  https://champagne-clone-convassist-1.thoughtsp...        NLS
# 433  https://champagne-clone-convassist-1.thoughtsp...        NLS
#
#                              worksheet_id  \
# 3    cd252e5c-b552-49a8-821d-3eadaa049cca
# 4    cd252e5c-b552-49a8-821d-3eadaa049cca
# 12   f67135f1-017f-4d66-8b21-112b51dcc9ed
# 13   f67135f1-017f-4d66-8b21-112b51dcc9ed
# 25   cd252e5c-b552-49a8-821d-3eadaa049cca
# ..                                    ...
# 372  b2d24878-0150-4c1e-a74c-bfc46cc4a682
# 417  971680a5-731c-4b6d-bfb6-1dd19745a020
# 418  971680a5-731c-4b6d-bfb6-1dd19745a020
# 432  37e44582-d602-4fcf-ab14-e20d378faa8b
# 433  37e44582-d602-4fcf-ab14-e20d378faa8b
#
#                                    msg_id  \
# 3    b05fe5b2-4ffc-4ab4-862f-7931a71735b9
# 4    25a5c86f-9f60-4635-8d45-08c7da15b7cf
# 12   377165be-25ff-45e7-a597-65635eab8328
# 13   669cf6c8-a8b6-41d1-84be-10e1e80ee946
# 25   ae8fb12f-8181-4ff5-aedf-9fb24ac97b93
# ..                                    ...
# 372  0d367697-4e96-42ab-a82f-7b2abeac5024
# 417  506d883a-1fc3-43c2-ab55-e4a6e4549a3c
# 418  f71f6862-4600-42c8-9f86-b7288a09c4bd
# 432  a392ea45-86a9-4e83-a19d-622d8b531a26
# 433  fd38230d-0147-4e88-894a-534408bd3999
#
#                                                  query  \
# 3                  sales and quantity in ca last month
# 4    do sweaters or jackets sell better in the fall...
# 12   Can you show this for top 3 loan purpose ? The...
# 13   Exclude debt consolidation and other while com...
# 25                                    show me all data
# ..                                                 ...
# 372                  break it down by person subregion
# 417  How many unique customer accounts asked a ques...
# 418  For this , Can you give the account name and t...
# 432            how many of those flights were delayed?
# 433         where were all those flights departing to?
#
#                                                    tml  \
# 3    [sales] [quantity purchased] [state] [date] = ...
# 4    sum [sales] [item type] [item type] = 'jackets...
# 12   [Loan Amount] [Purpose] [Purpose] in ( [Purpos...
# 13   [Loan Amount] [Purpose] [Purpose] in ( [Purpos...
# 25           [sales] [date] [date].monthly [item type]
# ..                                                 ...
# 372  sum [Person Mqls Count] [Person Subregion] [Pe...
# 417  unique count [Account ID] [Community User Feed...
# 418  count [Community User Feed Title] [Account Nam...
# 432  [Number of Flights] [DEPARTURE_COUNTRY_CODE] =...
# 433  count [ORIGIN_MESSAGE_ID] [ARRIVAL_IATA_AIRPOR...
#
#                                                    sql eval comment  \
# 3    select SUM(sales), SUM(quantity_purchased), st...            Y
# 4    select item_type, SUM(sales) from __Sample_Ret...            N
# 12   select SUM(Loan_Amount), Purpose from _Lending...            Y
# 13   select SUM(Loan_Amount), Purpose from _Lending...            Y
# 25   select date, item_type, sales from __Sample_Re...            Y
# ..                                                 ...          ...
# 372  SELECT Person_Subregion, SUM(Person_Mqls_Count...            Y
# 417  SELECT COUNT(DISTINCT Account_ID) FROM _GTM_Co...            N
# 418  SELECT Account_Name, COUNT(Community_User_Feed...            Y
# 432  SELECT Number_of_Flights FROM _OAG_Flight_Samp...            Y
# 433  SELECT ARRIVAL_IATA_AIRPORT_CODE, COUNT(*) as ...            Y
#
#          error type Unnamed: 12
# 3               NaN         NaN
# 4    filter missing         NaN
# 12              NaN         NaN
# 13              NaN         NaN
# 25              NaN         NaN
# ..              ...         ...
# 372             NaN         NaN
# 417     Date filter         NaN
# 418             NaN         NaN
# 432             NaN         NaN
# 433             NaN         NaN
#
# [78 rows x 13 columns]

# %%
# Total count of coversation with >= 2 msg


new2_unique_conv_id_count = new_result_df['conv_id'].nunique()
new2_unique_conv_id_count
# Out:
# 31

# %%
# Count & Precentage -  of failure for conv with >=2 msg(having one or more N)


# Calculate the count of 'conv_id' having count >= 2 and "N" in eval comment
selected_conv_ids_df = new_result_df[new_result_df['eval comment'] == 'N']['conv_id'].value_counts()

# Calculate total count and percentage
total_count1 = selected_conv_ids_df.shape[0]
total_percentage = (total_count1 / new_result_df['conv_id'].nunique()) * 100

# Display the results
print(f"Total count of 'conv_id' having count >= 2 and 'N' in 'eval comment': {total_count1}")
print(f"Percentage: {total_percentage:.2f}%")
# Out:
# Total count of 'conv_id' having count >= 2 and 'N' in 'eval comment': 12
# Percentage: 38.71%

# %%
# Count & Precentage -  of Success for conv with >=2 msg(having only Y)



Y_total_count=new2_unique_conv_id_count-total_count1

total_percentage = (Y_total_count / new_result_df['conv_id'].nunique()) * 100

print(f"Total count of 'conv_id' having count >= 2 and 'Y' in 'eval comment': {Y_total_count}")
print(f"Percentage: {total_percentage:.2f}%")
# Out:
# Total count of 'conv_id' having count >= 2 and 'Y' in 'eval comment': 19
# Percentage: 61.29%
